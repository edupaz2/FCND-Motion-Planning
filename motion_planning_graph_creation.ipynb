# %% [markdown]
# # Create flying node graph
# This Notebook will create the nodes graph using Voronoi approach and Networkx we will use for flying our drone. We do it once so we don't have to do it everytime we load the simulator.

# %% [markdown]
# ## Imports

# %%
import networkx as nx
nx.__version__

import numpy as np
from scipy.spatial import Voronoi
from bresenham import bresenham
from shapely.geometry import Polygon, Point, LineString
from queue import PriorityQueue
from planning_utils import heuristic, create_grid
import time

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# This is the same obstacle data from the previous lesson.
filename = 'colliders.csv'
data = np.loadtxt(filename, delimiter=',', dtype='Float64', skiprows=2)
print(data)
# Out:
# [[-310.2389   -439.2315     85.5         5.          5.         85.5     ]
#  [-300.2389   -439.2315     85.5         5.          5.         85.5     ]
#  [-290.2389   -439.2315     85.5         5.          5.         85.5     ]
#  ...
#  [ 257.8061    425.1645      1.75852     1.292725    1.292725    1.944791]
#  [ 293.9967    368.3391      3.557666    1.129456    1.129456    3.667319]
#  [ 281.5162    354.4156      4.999351    1.053772    1.053772    4.950246]]

# %%
print('start')
drone_altitude = 5
safety_distance = 3
grid, points, north_offset, east_offset = create_grid(data, drone_altitude, safety_distance)
print('done')
# Out:
# start
# done

# %% [markdown]
# ## Voronoi graph method

# %%
print('Creating Voronoi')
# Create a voronoi graph based on location of obstacle centres (2D no height)
t0 = time.time()
np_points = np.array(points)
voronoi_graph = Voronoi(np_points[:,:-1])
print('Voronoi Graph with {0} nodes'.format(len(voronoi_graph.vertices)))
print('Voronoi Graph took {0} seconds to build'.format(time.time()-t0))
# Out:
# Creating Voronoi
# Voronoi Graph with 5858 nodes
# Voronoi Graph took 0.09229564666748047 seconds to build

# %% [markdown]
# ## Create edges

# %%
import numpy.linalg as LA
from sklearn.neighbors import KDTree

def create_graph_from_voronoi(graph):
    g = nx.Graph()
    #nodes = tuple(map(tuple, voronoi_graph.vertices))
    #tree = KDTree(nodes)
    # Check each edge from graph.ridge_vertices for collision
    for v in graph.ridge_vertices:
        p1 = graph.vertices[v[0]]
        p2 = graph.vertices[v[1]]
        cells = list(bresenham(int(p1[0]), int(p1[1]), int(p2[0]), int(p2[1])))
        hit = False

        for c in cells:
            # First check if we're off the map
            if np.amin(c) < 0 or c[0] >= grid.shape[0] or c[1] >= grid.shape[1]:
                hit = True
                break
            # Next check if we're in collision
            if grid[c[0], c[1]] >= drone_altitude:
                hit = True
                break

        # If the edge does not hit on obstacle
        # add it to the list
        if not hit:
            dist = LA.norm(np.array(p2) - np.array(p1))
            g.add_edge((p1[0], p1[1]), (p2[0], p2[1]), weight=dist)
            #g.add_edge((p1[0], p1[1], drone_altitude), (p2[0], p2[1], drone_altitude), weight=dist)

    return g #, tree

print('Creating NxGraph')
t0 = time.time()
g = create_graph_from_voronoi(voronoi_graph)
print('Graph took {0} seconds to build'.format(time.time()-t0))
# Out:
# Creating NxGraph
# Graph took 28.50694227218628 seconds to build

# %%
print('Grid dimensions: ', grid.shape)
print('Voronoi vertices: ', len(voronoi_graph.vertices))
print('Voronoi ridge vertices: ', len(voronoi_graph.ridge_vertices))
print('Graph nodes: %5d' % len(g.nodes))
print('Graph edges: %5d' % len(g.edges))
# Out:
# Grid dimensions:  (921, 921)
# Voronoi vertices:  5858
# Voronoi ridge vertices:  9702
# Graph nodes:  1965
# Graph edges:  1895

# %% [markdown]
# ## Save to pickle

# %%
import pickle

# Dump the graph with Pickle
pkl_filename = 'graph.voronoi.p'

try:
    with open(pkl_filename, 'wb+') as pfile:
        print('Saving to pickle file ', pkl_filename)
        pickle.dump(
        {
            'graph': g,
            #'kdtree': t,
        },
        pfile, pickle.HIGHEST_PROTOCOL)
except Exception as e:
    print('Unable to save data to ', pkl_filename, ':', e)

print('done')
# Out:
# Saving to pickle file  graph.voronoi.p
# done

# %% [markdown]
# ## Load from pickle

# %%
import pickle

pkl_filename = 'graph.voronoi.p'
with open(pkl_filename, "rb") as pfile:
    print('Reading pickle')
    dist_pickle = pickle.load(pfile)

    g = dist_pickle['graph']
    #t = dist_pickle['kdtree']

print('done')
# Out:
# Reading pickle
# done

# %% [markdown]
# ## Visualize before pruning

# %%
import matplotlib.pyplot as plt
print('start')
# Plot it up!
fig = plt.figure(figsize=(10,10))
plt.imshow(grid, origin='lower', cmap='Greys') 

# Draw edges
# and connected nodes in red
for (n1, n2) in g.edges:
    plt.plot([n1[1], n2[1]], [n1[0], n2[0]], 'black', alpha=1)
    plt.scatter(n1[1], n1[0], c='red')
    plt.scatter(n2[1], n2[0], c='red')

plt.xlabel('EAST')
plt.ylabel('NORTH')
plt.show()
print('done')
# Out:
# start
# done

# %% [markdown]
# ## Prune

# %%
# Remove isolates
print('Removing isolates')
print('Before {0} nodes and {1} edges'.format(len(g.nodes), len(g.edges)))
g.remove_nodes_from(list(nx.isolates(g)))
print('After {0} nodes and {1} edges'.format(len(g.nodes), len(g.edges)))

def direct_line_between_nodes(p1, p2):
    cells = list(bresenham(int(p1[0]), int(p1[1]), int(p2[0]), int(p2[1])))
    for c in cells:
        # First check if we're off the map
        if np.amin(c) < 0 or c[0] >= grid.shape[0] or c[1] >= grid.shape[1]:
            return False
        # Next check if we're in collision
        if grid[c[0], c[1]] >= drone_altitude:
            return False
    return True

# Remove unnecessary nodes
print('Removing unnecessary nodes')
print('Before {0} nodes and {1} edges'.format(len(g.nodes), len(g.edges)))
to_remove = []
for n in g.nodes:
    if n not in to_remove:
        if g.degree(n) == 0:
            to_remove.append(n)
        elif g.degree(n) == 1:
            neighbor = list(g.neighbors(n))[0]
            if g.degree(neighbor) == 1:
                # Remove cycle pairs
                to_remove.append(n)
                to_remove.append(neighbor)
        elif g.degree(n) == 2:
            # Find the longest sequence of nodes connected without hit
            neighbors = list(g.neighbors(n))
            pred = neighbors[0]
            succ = neighbors[1]
            # Find predecessor
            visited = n
            while pred in to_remove:
                if g.degree(pred) != 2:
                    break
                neighbors = list(g.neighbors(pred))
                if neighbors[0] == visited:
                    visited = pred
                    pred = neighbors[1]
                else:
                    visited = pred
                    pred = neighbors[0]
            # Find successor
            visited = n
            while succ in to_remove:
                if g.degree(succ) != 2:
                    break
                neighbors = list(g.neighbors(succ))
                if neighbors[0] == visited:
                    visited = succ
                    succ = neighbors[1]
                else:
                    visited = succ
                    succ = neighbors[0]

            if direct_line_between_nodes(pred, succ):
                to_remove.append(n)
                dist = LA.norm(np.array(pred) - np.array(succ))
                g.add_edge(pred, succ, weight=dist)

g.remove_nodes_from(to_remove)
print('After {0} nodes and {1} edges'.format(len(g.nodes), len(g.edges)))
# Out:
# Removing isolates
# Before 1965 nodes and 1895 edges
# After 1965 nodes and 1895 edges
# Removing unnecessary nodes
# Before 1965 nodes and 1895 edges
# After 1180 nodes and 1236 edges

# %%
import pickle

# Dump the graph with Pickle
pkl_filename = 'graph.voronoi.prune.p'

try:
    with open(pkl_filename, 'wb+') as pfile:
        print('Saving to pickle file ', pkl_filename)
        pickle.dump(
        {
            'graph': g,
            #'kdtree': t,
        },
        pfile, pickle.HIGHEST_PROTOCOL)
except Exception as e:
    print('Unable to save data to ', pkl_filename, ':', e)

print('done')
# Out:
# Saving to pickle file  graph.voronoi.prune.p
# done

# %% [markdown]
# ## Visualize graph

# %%
import matplotlib.pyplot as plt
print('start')
# Plot it up!
fig = plt.figure(figsize=(10,10))
plt.imshow(grid, origin='lower', cmap='Greys') 

# Draw edges
# and connected nodes in red
for (n1, n2) in g.edges:
    plt.plot([n1[1], n2[1]], [n1[0], n2[0]], 'black', alpha=1)
    plt.scatter(n1[1], n1[0], c='red')
    plt.scatter(n2[1], n2[0], c='red')

plt.xlabel('EAST')
plt.ylabel('NORTH')
plt.show()
print('done')
# Out:
# start
# done

# %% [markdown]
# ## A*

# %%
from planning_utils import a_star_graph

rnd = np.random.randint(len(g.nodes))
start = list(g.nodes)[rnd]
print('Start: ', rnd)
rnd = np.random.randint(len(g.nodes))
print('Goal: ', rnd)
goal = list(g.nodes)[rnd]

path, cost = a_star_graph(g, heuristic, start, goal)
print(len(path), path)

try:
    path2 = nx.astar_path(g, start, goal)
    print(len(path2), path2)
except nx.NetworkXNoPath:
    print('No Path')

#path_pairs = zip(path[:-1], path[1:])
#for (n1, n2) in path_pairs:
#    print(n1, n2)
# Out:
# Start:  48
# Goal:  861
# Found a path.
# 36 [(280.76114, 325.76848), (290.76114, 325.768485), (304.60730943787485, 322.3069400443726), (306.9149857843195, 319.2300383260355), (320.76113895000003, 314.10178996113456), (340.76114, 310.7684516666739), (350.76114, 310.7685), (360.76114, 307.4351666666667), (365.76114, 304.5185), (378.2611409374985, 305.76849937500106), (380.76114, 304.10183333333333), (400.76114, 300.7685), (425.76114, 295.7685), (435.76112, 295.7685), (438.26111687499764, 298.2684943750008), (470.7611, 290.7685), (490.7611, 287.4351666666667), (500.76109999999994, 283.2685), (507.9039571428571, 285.0542142857143), (520.7610999999999, 280.7685), (540.7610999999999, 280.7685), (560.7610999999999, 277.4351666666667), (580.7610999999999, 270.7685), (580.7611300000399, 270.76846999996), (605.3065632231029, 269.8594264462059), (616.2157384299474, 261.67757231401055), (624.3325285714285, 260.0542142857143), (635.7610999999999, 265.7685), (650.7610999999999, 265.7685), (665.7610999999999, 260.7685), (688.2610999999999, 260.7685), (704.0944333333333, 284.10183333333333), (717.903957142857, 297.9113571428572), (710.7610999999999, 320.7685), (712.761096, 340.76848), (714.0944211111203, 344.10179944443985)]
# 37 [(280.76114, 325.76848), (290.76114, 325.768485), (304.60730943787485, 322.3069400443726), (306.9149857843195, 319.2300383260355), (320.76113895000003, 314.10178996113456), (340.76114, 310.7684516666739), (350.76114, 310.7685), (360.76114, 307.4351666666667), (365.76114, 304.5185), (378.2611409374985, 305.76849937500106), (380.76114, 304.10183333333333), (400.76114, 300.7685), (425.76114, 295.7685), (435.76112, 295.7685), (438.26111687499764, 298.2684943750008), (470.7611, 290.7685), (490.7611, 287.4351666666667), (500.76109999999994, 283.2685), (507.9039571428571, 285.0542142857143), (520.7610999999999, 280.7685), (540.7610999999999, 280.7685), (560.7610999999999, 277.4351666666667), (580.7610999999999, 270.7685), (580.7611300000399, 270.76846999996), (605.3065632231029, 269.8594264462059), (616.2157384299474, 261.67757231401055), (624.3325285714285, 260.0542142857143), (635.7610999999999, 265.7685), (650.7610999999999, 265.7685), (665.7610999999999, 260.7685), (688.2610999999999, 260.7685), (704.0944333333333, 284.10183333333333), (717.903957142857, 297.9113571428572), (710.7610999999999, 320.7685), (712.761096, 340.76848), (714.0944211111203, 344.10179944443985), (700.7610999999999, 350.76846)]

# %%
import matplotlib.pyplot as plt
print('start')
# Plot it up!
fig = plt.figure(figsize=(10,10))
plt.imshow(grid, origin='lower', cmap='Greys') 

# Draw edges
# and connected nodes in red
for (n1, n2) in g.edges:
    plt.plot([n1[1], n2[1]], [n1[0], n2[0]], 'black', alpha=1)
    plt.scatter(n1[1], n1[0], c='black')
    plt.scatter(n2[1], n2[0], c='black')

    
for i in range(len(path)-1):
    p1 = path[i]
    p2 = path[i+1]
    plt.plot([p1[1], p2[1]], [p1[0], p2[0]], 'r-')

for i in range(len(path2)-1):
    p1 = path2[i]
    p2 = path2[i+1]
    plt.plot([p1[1], p2[1]], [p1[0], p2[0]], 'b-')

    
plt.plot(start[1], start[0], 'gx')
plt.plot(goal[1], goal[0], 'gx')

plt.xlabel('EAST')
plt.ylabel('NORTH')
plt.show()
print('done')
# Out:
# start
# done
